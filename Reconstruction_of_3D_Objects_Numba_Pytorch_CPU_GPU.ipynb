# %% [markdown]
# <a href="https://colab.research.google.com/github/MZiaAfzal71/Reconstruction-of-3D-Objects-and-Parallelisation/blob/main/Reconstruction_of_3D_Objects_Numba_Pytorch_CPU_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the GitHub repository containing the source code and benchmark scripts
# !git clone https://github.com/MZiaAfzal71/Reconstruction-of-3D-Objects-and-Parallelisation/
# Out:
# Cloning into 'Reconstruction-of-3D-Objects-and-Parallelisation'...
# remote: Enumerating objects: 315, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 315 (delta 18), reused 22 (delta 8), pack-reused 271 (from 1)
# Receiving objects: 100% (315/315), 153.35 MiB | 17.29 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
# Change the current working directory to the cloned repository
# %cd Reconstruction-of-3D-Objects-and-Parallelisation
# Out:
# /content/Reconstruction-of-3D-Objects-and-Parallelisation

# %%
# Run the complete CPU benchmark pipeline.
#
# This script sequentially executes all CPU-based implementations
# (Python loops, NumPy, Numba, Numba parallel, and PyTorch CPU),
# together with the precision/continuity analysis and peak-memory
# measurements.
#
# Benchmark results are automatically saved to:
#   results/csv files/      - CSV files containing timing and memory statistics
#   results/pdf fig files/  - PDF figures generated during the analysis
#
# This step requires only CPU resources.

# !python driver\ scripts/generate_results_cpu.py
# Out:
# ===== Running info.py =====
#
#
# ===========================================================================
# 🚀 Diagnostic cell: captures exact hardware/software identity for the
# 🚀 Experimental Setup section (CPU model name, CPUID family/model number,
# 🚀 full Linux distribution, NumPy/Numba SIMD dispatch).
# ===========================================================================
# cpu_family: 6
# cpu_model_number: 79
# cpu_model_name: Intel(R) Xeon(R) CPU @ 2.20GHz
# distro: Ubuntu 22.04.5 LTS
# kernel: 6.6.122+
# numpy_version: 2.0.2
# numpy_simd: {'baseline': ['SSE', 'SSE2', 'SSE3'], 'found': ['SSSE3', 'SSE41', 'POPCNT', 'SSE42', 'AVX', 'F16C', 'FMA3', 'AVX2'], 'not found': ['AVX512F', 'AVX512CD', 'AVX512_KNL', 'AVX512_KNM', 'AVX512_SKX', 'AVX512_CLX', 'AVX512_CNL', 'AVX512_ICL']}
# numba_version: 0.60.0
# numba_target_cpu: host (auto-detected)
# numba_target_features: None
#
# ===== Running reconstruct_python_loops_cpu.py =====
#
#
# ===========================================================================
# 🚀 Surface Reconstruction Benchmark (Python (Numpy-Assisted) | CPU)
# ===========================================================================
# 🔬 Purpose  : Performance benchmarking for surface reconstruction
# 📊 Datasets : Banana, Apple, Vase
# 🧮 Parameters:
#    • n1 (horizontal points) : [300, 625, 1250]
#    • n2 (vertical points)   : [1200, 2500, 5000]
#    • Data types             : ['float64', 'float32']
#
# ⏳ This is a CPU-intensive benchmark.
# ☕ Please be patient while computations are in progress...
#
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 1.107965 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 1.180925 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 1.113952 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 1.123596 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 1.104934 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 1.113021 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 1.194848 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 1.919621 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 1.418127 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 1.103456 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 1.367297 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 1.367656 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 1.359097 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 1.400007 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 1.942803 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 2.094054 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 1.363947 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 1.384919 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 1.377691 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 1.379779 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 1.388512 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 2.039184 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 1.950923 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 1.391180 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 1.395188 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 1.403480 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 1.703626 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 1.381652 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 1.378884 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 2.438734 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 1.012180 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 1.028198 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 1.019718 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 1.010780 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 1.010832 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 1.022993 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 1.016554 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 1.018693 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 1.638762 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 1.679437 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 1.241944 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 1.235564 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 1.234711 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 1.231519 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 1.248973 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 1.238341 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 1.892523 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 1.841477 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 1.230324 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 1.233038 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 1.266695 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 1.263449 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 1.276114 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 1.261147 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 2.222546 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 1.520146 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 1.279445 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 1.254791 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 1.261056 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 1.259544 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 4.029037 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 2.770960 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 2.770049 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 2.755770 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 4.006889 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 2.755701 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 2.781953 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 2.754927 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 3.940982 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 2.747438 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 3.430651 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 4.692671 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 3.423315 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 3.489408 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 4.648939 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 3.436542 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 3.420951 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 4.365880 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 3.616751 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 3.447343 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 4.479926 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 3.464215 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for vase: 3.503525 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for vase: 4.722177 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for vase: 3.501179 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for vase: 3.495715 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for vase: 4.657227 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for vase: 3.477399 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for vase: 3.531072 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for vase: 4.321180 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 2.468965 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 2.489017 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 2.476719 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 3.675270 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 2.463155 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 2.521706 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 2.474527 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 3.268709 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 2.801555 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 2.501437 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 3.546300 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 3.546659 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 2.985807 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 2.985453 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 4.022751 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 3.048043 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 2.981781 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 2.977675 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 4.185217 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 2.973999 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 3.043409 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 4.319331 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for vase: 3.063814 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for vase: 3.073656 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for vase: 3.640952 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for vase: 3.593063 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for vase: 3.045064 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for vase: 3.047875 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for vase: 4.234119 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for vase: 3.054484 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for banana: 7.937858 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for banana: 8.592983 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for banana: 7.962638 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for banana: 8.238708 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for banana: 8.559890 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for banana: 7.793556 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for banana: 8.547787 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for banana: 8.549000 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for banana: 7.592081 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for banana: 8.710170 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for apple: 10.427080 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for apple: 9.947417 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for apple: 9.664778 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for apple: 10.575591 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for apple: 10.381593 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for apple: 10.369710 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for apple: 10.242983 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for apple: 9.287051 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for apple: 10.627653 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for apple: 10.343881 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for vase: 10.441960 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for vase: 9.444956 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for vase: 10.640578 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for vase: 10.634414 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for vase: 10.494756 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for vase: 10.480633 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for vase: 9.980927 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for vase: 9.951430 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for vase: 10.689806 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for vase: 10.460858 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for banana: 6.661298 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for banana: 7.331729 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for banana: 6.291106 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for banana: 7.357521 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for banana: 6.299763 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for banana: 7.475169 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for banana: 6.339472 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for banana: 7.631282 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for banana: 6.740169 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for banana: 6.995012 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for apple: 7.583847 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for apple: 8.856279 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for apple: 8.607183 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for apple: 7.659578 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for apple: 8.856619 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for apple: 8.596325 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for apple: 7.585907 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for apple: 9.002217 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for apple: 8.549403 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for apple: 7.533443 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for vase: 8.869872 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for vase: 7.780436 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for vase: 9.042597 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for vase: 8.815802 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for vase: 7.879422 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for vase: 8.970972 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for vase: 8.762324 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for vase: 8.073848 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for vase: 8.761536 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for vase: 8.791730 seconds
#
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_CPU_stats_banana_Colab.csv, /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_CPU_stats_apple_Colab.csv, and /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_CPU_stats_vase_Colab.csv.
#
#
# ---------------------------------------------------------------------------
# ⏱️ Benchmarking Phase Completed
# ---------------------------------------------------------------------------
# 🕒 Total benchmarking time: 15.41 minutes
# 📈 Timing data collected for all datasets and parameter combinations.
# ---------------------------------------------------------------------------
#
#
# ===========================================================================
# 🎨 Final Surface Reconstruction & Visualization
# ===========================================================================
# 📐 Objective : Reconstruct final 3D shapes using selected parameters
# 🔍 Focus     : Visual demonstration (not benchmarking)
# 📊 Shapes    : Banana, Apple, Vase
# ⚙️ Parameters: n1 = 500, n2 = 2000, dtype = float64
# 🖼️ Output    : High-quality 3D figures saved to PDF
# ===========================================================================
#
#
# ===========================================================================
# 📄 Visualization Completed Successfully 🎉
# ===========================================================================
#
#
#
# ===== Running reconstruct_numpy_vec_cpu.py =====
#
# Thread pools limited to 1: [{'user_api': 'blas', 'internal_api': 'openblas', 'num_threads': 1, 'prefix': 'libscipy_openblas', 'filepath': '/usr/local/lib/python3.12/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so', 'version': '0.3.27', 'threading_layer': 'pthreads', 'architecture': 'Haswell'}, {'user_api': 'openmp', 'internal_api': 'openmp', 'num_threads': 1, 'prefix': 'libgomp', 'filepath': '/usr/local/lib/python3.12/dist-packages/torch/lib/libgomp.so.1', 'version': None}]
#
# ===========================================================================
# 🚀 Surface Reconstruction Benchmark (Numpy Vectorized Single Thread | CPU)
# ===========================================================================
# 🔬 Purpose  : Performance benchmarking for surface reconstruction
# 📊 Datasets : Banana, Apple, Vase
# 🧮 Parameters:
#    • n1 (horizontal points) : [300, 625, 1250]
#    • n2 (vertical points)   : [1200, 2500, 5000]
#    • Data types             : ['float64', 'float32']
#
# ⏳ This is a CPU-intensive benchmark.
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 1.021068 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 1.026742 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 0.734408 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 0.728207 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 0.759111 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 0.739107 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 0.735944 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 0.739443 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 0.730714 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 0.743451 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 0.921801 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 0.939228 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 1.141561 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 1.281243 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 1.036407 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 0.917893 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 0.929170 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 0.923609 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 0.922581 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 0.935233 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 0.943668 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 0.944696 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 1.003057 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 1.268920 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 1.270323 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 0.966732 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 0.955849 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 0.966754 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 0.974693 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 0.939663 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 0.516881 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 0.510956 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 0.515849 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 0.505034 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 0.525061 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 0.513776 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 0.663720 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 0.758514 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 0.775167 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 0.682040 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 0.626671 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 0.595032 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 0.588976 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 0.596921 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 0.600210 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 0.592675 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 0.595229 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 0.611625 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 0.601580 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 0.591681 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 0.661200 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 0.742420 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 0.951857 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 0.954024 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 0.717181 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 0.669400 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 0.652034 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 0.656126 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 0.651184 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 0.660691 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 3.137834 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 3.574077 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 2.981395 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 3.008239 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 3.209857 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 3.454929 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 3.007348 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 3.025500 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 3.274973 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 3.352478 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 3.668121 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 4.449507 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 3.712151 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 3.726525 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 4.245588 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 3.722599 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 3.725103 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 4.205160 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 3.720318 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 3.724431 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 3.886616 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 3.794213 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for vase: 4.154301 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for vase: 4.088925 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for vase: 3.824727 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for vase: 4.050652 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for vase: 4.211896 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for vase: 3.804448 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for vase: 3.993006 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for vase: 4.282370 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 1.935551 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 1.935785 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 2.226681 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 2.375549 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 1.959505 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 1.964062 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 1.962978 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 1.952583 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 2.344391 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 2.253271 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 2.250077 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 2.256589 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 2.496244 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 2.748857 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 2.243800 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 2.275426 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 2.257367 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 2.467670 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 2.795677 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 2.258907 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 2.419768 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 2.756148 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for vase: 2.861019 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for vase: 2.415534 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for vase: 2.448093 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for vase: 2.424228 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for vase: 2.910959 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for vase: 2.477587 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for vase: 2.397257 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for vase: 2.410325 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for banana: 11.906095 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for banana: 11.857732 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for banana: 11.771848 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for banana: 11.765671 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for banana: 11.793173 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for banana: 11.789311 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for banana: 11.752933 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for banana: 11.886762 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for banana: 11.850239 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for banana: 11.694239 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for apple: 14.451115 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for apple: 14.533239 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for apple: 14.595920 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for apple: 14.487617 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for apple: 15.068602 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for apple: 14.721569 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for apple: 14.489245 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for apple: 14.526780 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for apple: 14.567694 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for apple: 14.520503 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for vase: 14.908862 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for vase: 14.737513 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for vase: 14.882247 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for vase: 14.833916 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for vase: 15.217283 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for vase: 14.953486 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for vase: 14.872296 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for vase: 14.921312 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for vase: 14.936121 seconds
# Data type: float64 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for vase: 15.077519 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for banana: 7.687614 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for banana: 7.243826 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for banana: 7.765709 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for banana: 7.706187 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for banana: 7.258932 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for banana: 7.758790 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for banana: 7.207360 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for banana: 8.121657 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for banana: 7.785637 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for banana: 7.227757 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for apple: 8.896183 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for apple: 8.371761 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for apple: 9.017192 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for apple: 8.913154 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for apple: 8.518228 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for apple: 9.198913 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for apple: 8.991950 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for apple: 8.853607 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for apple: 8.386952 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for apple: 8.941011 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 1th run for vase: 9.358014 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 2th run for vase: 9.455343 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 3th run for vase: 9.553678 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 4th run for vase: 9.539422 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 5th run for vase: 9.467714 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 6th run for vase: 9.148072 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 7th run for vase: 9.607917 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 8th run for vase: 9.560883 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 9th run for vase: 9.613044 seconds
# Data type: float32 n1 : 1250 n2 : 5000
#  Elapsed time 10th run for vase: 9.021493 seconds
#
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_NPVEC_ST_stats_banana_Colab.csv, /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_NPVEC_ST_stats_apple_Colab.csv, and /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Python_NPVEC_ST_stats_vase_Colab.csv.
#
#
# ---------------------------------------------------------------------------
# ⏱️ Benchmarking Phase Completed
# ---------------------------------------------------------------------------
# 🕒 Total benchmarking time: 17.04 minutes
# 📈 Timing data collected for all datasets and parameter combinations.
# ---------------------------------------------------------------------------
#
#
# ===========================================================================
# 🎨 Final Surface Reconstruction & Visualization
# ===========================================================================
#
#
# ===========================================================================
# 📄 Visualization Completed Successfully 🎉
# ===========================================================================
#
#
#
# ===== Running reconstruct_numba_cpu.py =====
#
#
# ===========================================================================
# 🚀 Surface Reconstruction Benchmark (Numba MultiThread | CPU)
# ===========================================================================
# 🔬 Purpose  : Performance benchmarking for surface reconstruction
# 📊 Datasets : Banana, Apple, Vase
# 🧮 Parameters:
#    • n1 (horizontal points) : [300, 625, 1250]
#    • n2 (vertical points)   : [1200, 2500, 5000]
#    • Data types             : ['float64', 'float32']
#
# ⏳ This is a CPU-intensive benchmark.
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 0.258787 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 0.272349 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 0.256441 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 0.269008 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 0.255633 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 0.263202 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 0.252729 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 0.267234 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 0.253820 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 0.263498 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 0.334238 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 0.323068 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 0.442412 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 0.487040 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 0.485116 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 0.468040 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 0.345805 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 0.322059 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 0.332727 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 0.323267 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 0.315944 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 0.312041 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 0.326093 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 0.315550 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 0.322005 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 0.316371 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 0.330617 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 0.315350 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 0.311764 seconds
# Data type: float64 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 0.316255 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for banana: 0.228245 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for banana: 0.223817 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for banana: 0.234998 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for banana: 0.227686 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for banana: 0.233901 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for banana: 0.221632 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for banana: 0.232673 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for banana: 0.220950 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for banana: 0.222448 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for banana: 0.222709 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for apple: 0.296926 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for apple: 0.283528 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for apple: 0.285206 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for apple: 0.291718 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for apple: 0.282926 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for apple: 0.299439 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for apple: 0.285309 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for apple: 0.285661 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for apple: 0.297936 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for apple: 0.285314 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 1th run for vase: 0.271059 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 2th run for vase: 0.272629 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 3th run for vase: 0.286473 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 4th run for vase: 0.272736 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 5th run for vase: 0.303242 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 6th run for vase: 0.404524 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 7th run for vase: 0.410848 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 8th run for vase: 0.391831 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 9th run for vase: 0.273052 seconds
# Data type: float32 n1 : 300 n2 : 1200
#  Elapsed time 10th run for vase: 0.280995 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 0.901589 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 0.904159 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 0.900039 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 0.901616 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 0.907130 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 1.058990 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 1.494076 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 0.901430 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 0.904690 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 0.903172 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 1.138334 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 1.131394 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 1.138542 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 1.854849 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 1.153026 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 1.141521 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 1.135417 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 1.162311 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 1.131691 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 1.138729 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 1.807091 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 1.117995 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 3th run for vase: 1.131521 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 4th run for vase: 1.112706 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 5th run for vase: 1.112270 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 6th run for vase: 1.119707 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 7th run for vase: 1.115341 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 8th run for vase: 1.445043 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 9th run for vase: 1.674074 seconds
# Data type: float64 n1 : 625 n2 : 2500
#  Elapsed time 10th run for vase: 1.129683 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for banana: 0.784262 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for banana: 0.781965 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for banana: 0.774019 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for banana: 0.766549 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for banana: 0.771437 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for banana: 0.781997 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for banana: 1.188259 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for banana: 1.101744 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for banana: 0.776967 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for banana: 0.777267 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for apple: 0.951842 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for apple: 0.952250 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 3th run for apple: 0.947980 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 4th run for apple: 0.950693 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 5th run for apple: 1.087205 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 6th run for apple: 1.490739 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 7th run for apple: 0.971086 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 8th run for apple: 0.958446 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 9th run for apple: 0.940638 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 10th run for apple: 0.951850 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 1th run for vase: 0.959308 seconds
# Data type: float32 n1 : 625 n2 : 2500
#  Elapsed time 2th run for vase: 0.957103 seconds
# Data type: float32 n1 : 625 n2 : 2500
# ...
# [apple] dtype=float64 n1=300 n2=1200 run 1/10: total=0.7160s kernel=0.5182s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 2/10: total=0.6931s kernel=0.5102s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 3/10: total=0.6985s kernel=0.5188s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 4/10: total=0.7006s kernel=0.5055s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 5/10: total=0.6903s kernel=0.5102s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 6/10: total=0.7007s kernel=0.5201s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 7/10: total=0.6932s kernel=0.5113s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 8/10: total=0.6842s kernel=0.5021s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 9/10: total=0.6928s kernel=0.5042s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=300 n2=1200 run 10/10: total=0.8526s kernel=0.6306s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 1/10: total=0.8825s kernel=0.6366s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 2/10: total=0.6973s kernel=0.5151s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 3/10: total=0.6923s kernel=0.5076s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 4/10: total=0.6912s kernel=0.5065s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 5/10: total=0.7008s kernel=0.5063s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 6/10: total=0.7001s kernel=0.5191s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 7/10: total=0.6956s kernel=0.5144s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 8/10: total=0.6943s kernel=0.5094s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 9/10: total=0.7025s kernel=0.5079s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=300 n2=1200 run 10/10: total=0.7006s kernel=0.5193s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 1/10: total=0.2979s kernel=0.2263s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 2/10: total=0.2851s kernel=0.2165s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 3/10: total=0.2840s kernel=0.2153s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 4/10: total=0.2881s kernel=0.2191s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 5/10: total=0.2876s kernel=0.2187s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 6/10: total=0.3710s kernel=0.3017s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 7/10: total=0.4082s kernel=0.3146s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 8/10: total=0.4029s kernel=0.3112s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 9/10: total=0.4020s kernel=0.3098s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=300 n2=1200 run 10/10: total=0.4068s kernel=0.3127s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 1/10: total=0.3627s kernel=0.2799s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 2/10: total=0.3603s kernel=0.2773s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 3/10: total=0.3687s kernel=0.2846s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 4/10: total=0.3542s kernel=0.2697s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 5/10: total=0.3584s kernel=0.2750s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 6/10: total=0.3572s kernel=0.2743s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 7/10: total=0.3543s kernel=0.2708s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 8/10: total=0.3689s kernel=0.2776s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 9/10: total=0.3546s kernel=0.2719s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=300 n2=1200 run 10/10: total=0.3616s kernel=0.2770s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 1/10: total=0.3640s kernel=0.2787s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 2/10: total=0.3621s kernel=0.2758s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 3/10: total=0.3630s kernel=0.2777s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 4/10: total=0.3617s kernel=0.2763s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 5/10: total=0.3746s kernel=0.2736s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 6/10: total=0.3639s kernel=0.2759s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 7/10: total=0.3627s kernel=0.2756s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 8/10: total=0.3717s kernel=0.2836s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 9/10: total=0.3635s kernel=0.2769s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=300 n2=1200 run 10/10: total=0.3724s kernel=0.2870s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 1/10: total=2.3458s kernel=1.7900s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 2/10: total=2.3461s kernel=1.7783s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 3/10: total=2.5374s kernel=1.9738s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 4/10: total=2.6794s kernel=2.1067s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 5/10: total=2.7515s kernel=2.0072s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 6/10: total=2.3572s kernel=1.7930s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 7/10: total=2.5369s kernel=1.9613s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 8/10: total=2.5231s kernel=1.9572s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 9/10: total=2.6327s kernel=2.0584s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=625 n2=2500 run 10/10: total=2.5556s kernel=1.7897s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 1/10: total=3.1167s kernel=2.4219s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 2/10: total=3.4829s kernel=2.7756s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 3/10: total=3.1322s kernel=2.2661s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 4/10: total=3.0441s kernel=2.3406s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 5/10: total=3.0044s kernel=2.3035s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 6/10: total=3.4134s kernel=2.7215s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 7/10: total=3.1161s kernel=2.4095s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 8/10: total=3.1325s kernel=2.4175s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 9/10: total=2.9763s kernel=2.2778s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=625 n2=2500 run 10/10: total=3.6073s kernel=2.7529s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 1/10: total=3.1315s kernel=2.4262s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 2/10: total=3.3203s kernel=2.6005s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 3/10: total=3.6177s kernel=2.6988s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 4/10: total=3.1331s kernel=2.4279s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 5/10: total=3.1306s kernel=2.4263s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 6/10: total=3.5049s kernel=2.8065s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 7/10: total=3.1511s kernel=2.3232s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 8/10: total=2.9843s kernel=2.2757s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 9/10: total=3.1610s kernel=2.4515s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=625 n2=2500 run 10/10: total=3.7131s kernel=3.0109s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 1/10: total=1.2690s kernel=0.9750s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 2/10: total=1.2725s kernel=0.9757s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 3/10: total=1.2822s kernel=0.9780s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 4/10: total=1.2659s kernel=0.9726s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 5/10: total=1.2715s kernel=0.9755s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 6/10: total=1.2925s kernel=0.9891s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 7/10: total=1.7160s kernel=1.3198s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 8/10: total=1.4549s kernel=1.0590s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 9/10: total=1.2711s kernel=0.9768s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float32 n1=625 n2=2500 run 10/10: total=1.2767s kernel=0.9825s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 1/10: total=1.5868s kernel=1.2232s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 2/10: total=1.5860s kernel=1.2148s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 3/10: total=1.7790s kernel=1.4147s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 4/10: total=2.1037s kernel=1.6261s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 5/10: total=1.5817s kernel=1.2140s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 6/10: total=1.5639s kernel=1.1935s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 7/10: total=1.5836s kernel=1.2198s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 8/10: total=1.5821s kernel=1.2164s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 9/10: total=1.5919s kernel=1.2179s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float32 n1=625 n2=2500 run 10/10: total=1.7627s kernel=1.4001s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 1/10: total=1.5957s kernel=1.2300s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 2/10: total=1.6010s kernel=1.2310s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 3/10: total=1.6095s kernel=1.2366s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 4/10: total=1.6097s kernel=1.2422s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 5/10: total=1.5981s kernel=1.2334s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 6/10: total=1.8050s kernel=1.4319s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 7/10: total=2.1022s kernel=1.6009s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 8/10: total=1.6060s kernel=1.2269s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 9/10: total=1.6078s kernel=1.2388s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float32 n1=625 n2=2500 run 10/10: total=1.6020s kernel=1.2345s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 1/10: total=10.6705s kernel=8.4986s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 2/10: total=10.8226s kernel=8.6326s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 3/10: total=10.4650s kernel=8.2722s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 4/10: total=10.4455s kernel=7.9877s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 5/10: total=10.8020s kernel=8.0694s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 6/10: total=10.8315s kernel=8.6174s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 7/10: total=10.7439s kernel=8.5661s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 8/10: total=10.6836s kernel=8.5159s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 9/10: total=10.8504s kernel=8.6437s h2d=0.00000s d2h=0.00000s
# [banana] dtype=float64 n1=1250 n2=5000 run 10/10: total=10.4493s kernel=8.2816s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 1/10: total=13.1005s kernel=10.3405s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 2/10: total=13.0403s kernel=10.2858s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 3/10: total=13.0971s kernel=10.3367s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 4/10: total=13.0416s kernel=10.3001s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 5/10: total=13.1977s kernel=10.4610s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 6/10: total=13.1251s kernel=10.3836s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 7/10: total=13.1856s kernel=10.4611s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 8/10: total=13.1968s kernel=10.4468s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 9/10: total=13.2898s kernel=10.5142s h2d=0.00000s d2h=0.00000s
# [apple] dtype=float64 n1=1250 n2=5000 run 10/10: total=13.2424s kernel=10.2169s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 1/10: total=13.5892s kernel=10.1763s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 2/10: total=13.5004s kernel=10.4354s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 3/10: total=13.3147s kernel=10.5666s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 4/10: total=13.3208s kernel=10.5801s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 5/10: total=13.1082s kernel=10.3780s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 6/10: total=13.2094s kernel=10.4438s h2d=0.00000s d2h=0.00000s
# [vase] dtype=float64 n1=1250 n2=5000 run 7/10: total=13.1243s kernel=10.3768s h2d=0.00000s d2h=0.00000s
# Traceback (most recent call last):
#   File "/content/Reconstruction-of-3D-Objects-and-Parallelisation/code/reconstruct_pytorch_cpu.py", line 162, in <module>
#     time_taken = run_pytorch_benchmark(N1, N2, dtypes, objects, device, R=10, warmup=1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Reconstruction-of-3D-Objects-and-Parallelisation/code/reconstruct_pytorch_cpu.py", line 104, in run_pytorch_benchmark
#     surf_pts_inplace_vectorized(Rm, N, tot_pts, Z, B_Point, C_Point, B, T,
#   File "/content/Reconstruction-of-3D-Objects-and-Parallelisation/code/surfaces/surfaces_pytorch.py", line 574, in surf_pts_inplace_vectorized
#     FR0x.add_(B0[:, 0].unsqueeze(-1) * L1_m)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/content/Reconstruction-of-3D-Objects-and-Parallelisation/driver scripts/generate_results_cpu.py", line 27, in <module>
#     result = subprocess.run(
#              ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# Run the complete GPU benchmark pipeline.
#
# IMPORTANT:
# Before executing this cell, enable a GPU runtime (Runtime → Change runtime type → GPU in Colab,
# or enable GPU acceleration in Kaggle).
#
# If the runtime has restarted after enabling the GPU, rerun the repository
# setup cells above (clone the GitHub repository and change to the project
# directory) before executing this command.
#
# This script benchmarks the GPU implementations (Numba CUDA and PyTorch CUDA)
# and stores the generated CSV files in:
#   results/csv files/

# !python driver\ scripts/generate_results_gpu.py
# Out:
# ===== Running info.py =====
#
#
# ===========================================================================
# 🚀 Diagnostic cell: captures exact hardware/software identity for the
# 🚀 Experimental Setup section (CPU model name, CPUID family/model number,
# 🚀 full Linux distribution, NumPy/Numba SIMD dispatch).
# ===========================================================================
# cpu_family: 6
# cpu_model_number: 85
# cpu_model_name: Intel(R) Xeon(R) CPU @ 2.00GHz
# distro: Ubuntu 22.04.5 LTS
# kernel: 6.6.122+
# numpy_version: 2.0.2
# numpy_simd: {'baseline': ['SSE', 'SSE2', 'SSE3'], 'found': ['SSSE3', 'SSE41', 'POPCNT', 'SSE42', 'AVX', 'F16C', 'FMA3', 'AVX2', 'AVX512F', 'AVX512CD', 'AVX512_SKX'], 'not found': ['AVX512_KNL', 'AVX512_KNM', 'AVX512_CLX', 'AVX512_CNL', 'AVX512_ICL']}
# numba_version: 0.60.0
# numba_target_cpu: host (auto-detected)
# numba_target_features: None
#
# ===== Running reconstruct_numba_gpu.py =====
#
#
# ===========================================================================
# 🚀 Surface Reconstruction Benchmark (Numba | GPU)
# ===========================================================================
# 🔬 Purpose  : Performance benchmarking for surface reconstruction
# 📊 Datasets : Banana, Apple, Vase
# 🧮 Parameters:
#    • n1 (horizontal points) : [300, 625, 1250]
#    • n2 (vertical points)   : [1200, 2500, 5000]
#    • Data types             : ['float64', 'float32']
#
# ⏳ This is a GPU-intensive benchmark.
# [banana] dtype=float64 n1=300 n2=1200 run 1/10: total=0.0726s kernel=0.0185s h2d=0.00386s d2h=0.04916s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 2/10: total=0.0758s kernel=0.0187s h2d=0.00875s d2h=0.04739s gpu_mem=0.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 3/10: total=0.0719s kernel=0.0185s h2d=0.00382s d2h=0.04853s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 4/10: total=0.0757s kernel=0.0188s h2d=0.00732s d2h=0.04867s gpu_mem=0.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 5/10: total=0.0726s kernel=0.0185s h2d=0.00354s d2h=0.04962s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 6/10: total=0.0718s kernel=0.0168s h2d=0.00352s d2h=0.05054s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 7/10: total=0.0713s kernel=0.0169s h2d=0.00346s d2h=0.05000s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 8/10: total=0.0707s kernel=0.0168s h2d=0.00385s d2h=0.04902s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 9/10: total=0.0715s kernel=0.0168s h2d=0.00399s d2h=0.04973s gpu_mem=136.0MB
# [banana] dtype=float64 n1=300 n2=1200 run 10/10: total=0.0714s kernel=0.0169s h2d=0.00383s d2h=0.04971s gpu_mem=136.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 1/10: total=0.0877s kernel=0.0202s h2d=0.00416s d2h=0.06224s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 2/10: total=0.0997s kernel=0.0196s h2d=0.00799s d2h=0.07067s gpu_mem=0.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 3/10: total=0.0889s kernel=0.0195s h2d=0.00409s d2h=0.06391s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 4/10: total=0.0921s kernel=0.0195s h2d=0.00776s d2h=0.06362s gpu_mem=0.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 5/10: total=0.0879s kernel=0.0195s h2d=0.00367s d2h=0.06365s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 6/10: total=0.0879s kernel=0.0195s h2d=0.00417s d2h=0.06292s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 7/10: total=0.0867s kernel=0.0196s h2d=0.00373s d2h=0.06234s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 8/10: total=0.0863s kernel=0.0196s h2d=0.00464s d2h=0.06089s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 9/10: total=0.0867s kernel=0.0195s h2d=0.00372s d2h=0.06202s gpu_mem=168.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 10/10: total=0.0884s kernel=0.0195s h2d=0.00370s d2h=0.06399s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 1/10: total=0.0942s kernel=0.0199s h2d=0.00510s d2h=0.06769s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 2/10: total=0.0906s kernel=0.0199s h2d=0.00788s d2h=0.06136s gpu_mem=0.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 3/10: total=0.0889s kernel=0.0199s h2d=0.00348s d2h=0.06442s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 4/10: total=0.0915s kernel=0.0199s h2d=0.00769s d2h=0.06268s gpu_mem=0.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 5/10: total=0.0877s kernel=0.0198s h2d=0.00370s d2h=0.06300s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 6/10: total=0.0904s kernel=0.0199s h2d=0.00425s d2h=0.06484s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 7/10: total=0.0891s kernel=0.0199s h2d=0.00376s d2h=0.06410s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 8/10: total=0.0886s kernel=0.0199s h2d=0.00415s d2h=0.06315s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 9/10: total=0.0910s kernel=0.0199s h2d=0.00424s d2h=0.06541s gpu_mem=168.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 10/10: total=0.0928s kernel=0.0200s h2d=0.00449s d2h=0.06685s gpu_mem=168.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 1/10: total=0.0662s kernel=0.0098s h2d=0.00389s d2h=0.05141s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 2/10: total=0.0697s kernel=0.0099s h2d=0.00805s d2h=0.05074s gpu_mem=0.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 3/10: total=0.0655s kernel=0.0097s h2d=0.00377s d2h=0.05090s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 4/10: total=0.0690s kernel=0.0098s h2d=0.00727s d2h=0.05082s gpu_mem=0.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 5/10: total=0.0655s kernel=0.0098s h2d=0.00397s d2h=0.05040s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 6/10: total=0.0649s kernel=0.0098s h2d=0.00369s d2h=0.05029s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 7/10: total=0.0644s kernel=0.0098s h2d=0.00362s d2h=0.04986s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 8/10: total=0.0672s kernel=0.0098s h2d=0.00381s d2h=0.05260s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 9/10: total=0.0648s kernel=0.0098s h2d=0.00366s d2h=0.05020s gpu_mem=136.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 10/10: total=0.0721s kernel=0.0098s h2d=0.00360s d2h=0.05763s gpu_mem=136.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 1/10: total=0.0762s kernel=0.0084s h2d=0.00361s d2h=0.06282s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 2/10: total=0.0803s kernel=0.0085s h2d=0.00833s d2h=0.06227s gpu_mem=0.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 3/10: total=0.0753s kernel=0.0084s h2d=0.00374s d2h=0.06179s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 4/10: total=0.0807s kernel=0.0085s h2d=0.00763s d2h=0.06322s gpu_mem=0.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 5/10: total=0.0771s kernel=0.0084s h2d=0.00480s d2h=0.06251s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 6/10: total=0.0800s kernel=0.0085s h2d=0.00414s d2h=0.06585s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 7/10: total=0.0750s kernel=0.0085s h2d=0.00339s d2h=0.06176s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 8/10: total=0.0765s kernel=0.0084s h2d=0.00344s d2h=0.06344s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 9/10: total=0.0751s kernel=0.0085s h2d=0.00342s d2h=0.06183s gpu_mem=168.0MB
# [apple] dtype=float32 n1=300 n2=1200 run 10/10: total=0.0749s kernel=0.0084s h2d=0.00356s d2h=0.06170s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 1/10: total=0.0763s kernel=0.0101s h2d=0.00361s d2h=0.06130s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 2/10: total=0.0850s kernel=0.0103s h2d=0.00797s d2h=0.06547s gpu_mem=0.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 3/10: total=0.0759s kernel=0.0102s h2d=0.00348s d2h=0.06105s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 4/10: total=0.0828s kernel=0.0102s h2d=0.00772s d2h=0.06357s gpu_mem=0.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 5/10: total=0.0776s kernel=0.0102s h2d=0.00381s d2h=0.06215s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 6/10: total=0.0793s kernel=0.0102s h2d=0.00342s d2h=0.06432s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 7/10: total=0.0795s kernel=0.0104s h2d=0.00516s d2h=0.06249s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 8/10: total=0.0787s kernel=0.0102s h2d=0.00372s d2h=0.06353s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 9/10: total=0.0807s kernel=0.0102s h2d=0.00394s d2h=0.06497s gpu_mem=168.0MB
# [vase] dtype=float32 n1=300 n2=1200 run 10/10: total=0.0798s kernel=0.0103s h2d=0.00390s d2h=0.06409s gpu_mem=168.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 1/10: total=0.2736s kernel=0.0532s h2d=0.00439s d2h=0.21477s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 2/10: total=0.2751s kernel=0.0531s h2d=0.00997s d2h=0.21095s gpu_mem=0.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 3/10: total=0.2572s kernel=0.0413s h2d=0.00391s d2h=0.21082s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 4/10: total=0.2668s kernel=0.0413s h2d=0.00809s d2h=0.21631s gpu_mem=0.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 5/10: total=0.2525s kernel=0.0345s h2d=0.00381s d2h=0.21322s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 6/10: total=0.2533s kernel=0.0344s h2d=0.00572s d2h=0.21211s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 7/10: total=0.3021s kernel=0.0312s h2d=0.00941s d2h=0.26022s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 8/10: total=0.2791s kernel=0.0304s h2d=0.00580s d2h=0.24198s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 9/10: total=0.2780s kernel=0.0304s h2d=0.00572s d2h=0.24075s gpu_mem=574.0MB
# [banana] dtype=float64 n1=625 n2=2500 run 10/10: total=0.2760s kernel=0.0307s h2d=0.00549s d2h=0.23868s gpu_mem=574.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 1/10: total=0.3505s kernel=0.0406s h2d=0.00710s d2h=0.30127s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 2/10: total=0.3752s kernel=0.0433s h2d=0.01145s d2h=0.31917s gpu_mem=0.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 3/10: total=0.3108s kernel=0.0374s h2d=0.00452s d2h=0.26750s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 4/10: total=0.3112s kernel=0.0375s h2d=0.00844s d2h=0.26391s gpu_mem=0.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 5/10: total=0.3130s kernel=0.0387s h2d=0.00430s d2h=0.26864s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 6/10: total=0.3237s kernel=0.0373s h2d=0.00451s d2h=0.28054s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 7/10: total=0.3218s kernel=0.0372s h2d=0.00452s d2h=0.27866s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 8/10: total=0.3241s kernel=0.0357s h2d=0.00457s d2h=0.28231s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 9/10: total=0.3143s kernel=0.0372s h2d=0.00426s d2h=0.27127s gpu_mem=718.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 10/10: total=0.3123s kernel=0.0372s h2d=0.00440s d2h=0.26929s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 1/10: total=0.3163s kernel=0.0378s h2d=0.00439s d2h=0.27270s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 2/10: total=0.3164s kernel=0.0388s h2d=0.00841s d2h=0.26770s gpu_mem=0.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 3/10: total=0.3165s kernel=0.0368s h2d=0.00430s d2h=0.27421s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 4/10: total=0.3192s kernel=0.0388s h2d=0.00818s d2h=0.27090s gpu_mem=0.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 5/10: total=0.3134s kernel=0.0381s h2d=0.00460s d2h=0.26927s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 6/10: total=0.3200s kernel=0.0379s h2d=0.00565s d2h=0.27513s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 7/10: total=0.3092s kernel=0.0370s h2d=0.00430s d2h=0.26653s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 8/10: total=0.3099s kernel=0.0367s h2d=0.00488s d2h=0.26673s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 9/10: total=0.3286s kernel=0.0381s h2d=0.00442s d2h=0.28461s gpu_mem=718.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 10/10: total=0.3122s kernel=0.0373s h2d=0.00449s d2h=0.26906s gpu_mem=718.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 1/10: total=0.2520s kernel=0.0250s h2d=0.00422s d2h=0.22145s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 2/10: total=0.2613s kernel=0.0260s h2d=0.00828s d2h=0.22562s gpu_mem=0.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 3/10: total=0.2477s kernel=0.0252s h2d=0.00429s d2h=0.21696s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 4/10: total=0.2582s kernel=0.0262s h2d=0.00811s d2h=0.22258s gpu_mem=0.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 5/10: total=0.2462s kernel=0.0252s h2d=0.00417s d2h=0.21556s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 6/10: total=0.2616s kernel=0.0256s h2d=0.00656s d2h=0.22813s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 7/10: total=0.2462s kernel=0.0252s h2d=0.00426s d2h=0.21540s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 8/10: total=0.2584s kernel=0.0253s h2d=0.00578s d2h=0.22601s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 9/10: total=0.2425s kernel=0.0252s h2d=0.00394s d2h=0.21199s gpu_mem=574.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 10/10: total=0.2459s kernel=0.0254s h2d=0.00413s d2h=0.21529s gpu_mem=574.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 1/10: total=0.3499s kernel=0.0315s h2d=0.00423s d2h=0.31284s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 2/10: total=0.3489s kernel=0.0333s h2d=0.01008s d2h=0.30399s gpu_mem=0.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 3/10: total=0.3300s kernel=0.0319s h2d=0.00512s d2h=0.29169s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 4/10: total=0.3357s kernel=0.0330s h2d=0.01055s d2h=0.29077s gpu_mem=0.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 5/10: total=0.3713s kernel=0.0316s h2d=0.00511s d2h=0.33324s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 6/10: total=0.3519s kernel=0.0316s h2d=0.00575s d2h=0.31283s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 7/10: total=0.3426s kernel=0.0311s h2d=0.00601s d2h=0.30374s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 8/10: total=0.3029s kernel=0.0310s h2d=0.00504s d2h=0.26541s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 9/10: total=0.3030s kernel=0.0310s h2d=0.00549s d2h=0.26497s gpu_mem=718.0MB
# [apple] dtype=float32 n1=625 n2=2500 run 10/10: total=0.2980s kernel=0.0310s h2d=0.00403s d2h=0.26124s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 1/10: total=0.2994s kernel=0.0314s h2d=0.00411s d2h=0.26241s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 2/10: total=0.3013s kernel=0.0328s h2d=0.00878s d2h=0.25830s gpu_mem=0.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 3/10: total=0.3113s kernel=0.0313s h2d=0.00395s d2h=0.27466s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 4/10: total=0.3070s kernel=0.0329s h2d=0.00818s d2h=0.26444s gpu_mem=0.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 5/10: total=0.3029s kernel=0.0312s h2d=0.00413s d2h=0.26613s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 6/10: total=0.3147s kernel=0.0313s h2d=0.00606s d2h=0.27597s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 7/10: total=0.3007s kernel=0.0312s h2d=0.00415s d2h=0.26368s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 8/10: total=0.3024s kernel=0.0313s h2d=0.00474s d2h=0.26498s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 9/10: total=0.3063s kernel=0.0313s h2d=0.00384s d2h=0.26982s gpu_mem=718.0MB
# [vase] dtype=float32 n1=625 n2=2500 run 10/10: total=0.3035s kernel=0.0311s h2d=0.00429s d2h=0.26663s gpu_mem=718.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 1/10: total=1.0267s kernel=0.1499s h2d=0.00453s d2h=0.87083s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 2/10: total=1.0318s kernel=0.1526s h2d=0.01365s d2h=0.86407s gpu_mem=2.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 3/10: total=0.9871s kernel=0.1505s h2d=0.00511s d2h=0.83009s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 4/10: total=1.0582s kernel=0.1534s h2d=0.01331s d2h=0.89030s gpu_mem=0.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 5/10: total=1.1167s kernel=0.1509s h2d=0.00832s d2h=0.95588s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 6/10: total=1.1529s kernel=0.1534s h2d=0.01039s d2h=0.98774s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 7/10: total=1.0067s kernel=0.1507s h2d=0.00490s d2h=0.84965s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 8/10: total=1.0079s kernel=0.1535s h2d=0.00916s d2h=0.84390s gpu_mem=2292.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 9/10: total=1.0006s kernel=0.1515s h2d=0.00453s d2h=0.84314s gpu_mem=2294.0MB
# [banana] dtype=float64 n1=1250 n2=5000 run 10/10: total=1.0131s kernel=0.1533s h2d=0.00829s d2h=0.85001s gpu_mem=2292.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 1/10: total=1.2448s kernel=0.1880s h2d=0.00457s d2h=1.05063s gpu_mem=2868.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 2/10: total=1.2643s kernel=0.1925s h2d=0.01280s d2h=1.05722s gpu_mem=0.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 3/10: total=1.2587s kernel=0.1891s h2d=0.00544s d2h=1.06253s gpu_mem=2866.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 4/10: total=1.3460s kernel=0.1929s h2d=0.01386s d2h=1.13758s gpu_mem=0.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 5/10: total=1.3912s kernel=0.1887s h2d=0.00776s d2h=1.19304s gpu_mem=2866.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 6/10: total=1.2544s kernel=0.1922s h2d=0.01022s d2h=1.04996s gpu_mem=2868.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 7/10: total=1.2547s kernel=0.1897s h2d=0.00474s d2h=1.05834s gpu_mem=2868.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 8/10: total=1.2516s kernel=0.1932s h2d=0.00984s d2h=1.04696s gpu_mem=2868.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 9/10: total=1.2511s kernel=0.1906s h2d=0.00542s d2h=1.05339s gpu_mem=2868.0MB
# [apple] dtype=float64 n1=1250 n2=5000 run 10/10: total=1.2508s kernel=0.1928s h2d=0.00892s d2h=1.04741s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 1/10: total=1.2547s kernel=0.1957s h2d=0.00442s d2h=1.05286s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 2/10: total=1.3276s kernel=0.1998s h2d=0.01291s d2h=1.11319s gpu_mem=0.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 3/10: total=1.3721s kernel=0.1959s h2d=0.00704s d2h=1.16741s gpu_mem=2866.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 4/10: total=1.2896s kernel=0.2000s h2d=0.01914s d2h=1.06875s gpu_mem=0.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 5/10: total=1.2849s kernel=0.1962s h2d=0.00546s d2h=1.08172s gpu_mem=2866.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 6/10: total=1.2721s kernel=0.2012s h2d=0.00862s d2h=1.06068s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 7/10: total=1.3089s kernel=0.1975s h2d=0.00455s d2h=1.10524s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 8/10: total=1.2697s kernel=0.2005s h2d=0.00889s d2h=1.05867s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 9/10: total=1.2613s kernel=0.1977s h2d=0.00478s d2h=1.05719s gpu_mem=2868.0MB
# [vase] dtype=float64 n1=1250 n2=5000 run 10/10: total=1.2644s kernel=0.2013s h2d=0.00852s d2h=1.05295s gpu_mem=2868.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 1/10: total=1.0805s kernel=0.1088s h2d=0.00514s d2h=0.96506s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 2/10: total=1.1250s kernel=0.1152s h2d=0.01393s d2h=0.99434s gpu_mem=0.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 3/10: total=0.9904s kernel=0.1089s h2d=0.00816s d2h=0.87168s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 4/10: total=0.9840s kernel=0.1161s h2d=0.01527s d2h=0.85113s gpu_mem=0.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 5/10: total=0.9631s kernel=0.1098s h2d=0.00728s d2h=0.84447s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 6/10: total=0.9685s kernel=0.1169s h2d=0.00707s d2h=0.84318s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 7/10: total=0.9607s kernel=0.1113s h2d=0.00490s d2h=0.84304s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 8/10: total=0.9890s kernel=0.1159s h2d=0.00786s d2h=0.86379s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 9/10: total=0.9606s kernel=0.1098s h2d=0.00461s d2h=0.84477s gpu_mem=2292.0MB
# [banana] dtype=float32 n1=1250 n2=5000 run 10/10: total=0.9957s kernel=0.1124s h2d=0.00749s d2h=0.87448s gpu_mem=2292.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 1/10: total=1.2557s kernel=0.1362s h2d=0.00505s d2h=1.11265s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 2/10: total=1.3501s kernel=0.1434s h2d=0.01418s d2h=1.19013s gpu_mem=0.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 3/10: total=1.2663s kernel=0.1359s h2d=0.00684s d2h=1.12169s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 4/10: total=1.2269s kernel=0.1445s h2d=0.01181s d2h=1.06866s gpu_mem=0.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 5/10: total=1.1902s kernel=0.1356s h2d=0.00524s d2h=1.04759s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 6/10: total=1.2162s kernel=0.1447s h2d=0.00806s d2h=1.06160s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 7/10: total=1.1980s kernel=0.1354s h2d=0.00529s d2h=1.05543s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 8/10: total=1.2044s kernel=0.1430s h2d=0.00706s d2h=1.05275s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 9/10: total=1.1845s kernel=0.1350s h2d=0.00451s d2h=1.04319s gpu_mem=2866.0MB
# [apple] dtype=float32 n1=1250 n2=5000 run 10/10: total=1.2195s kernel=0.1379s h2d=0.00777s d2h=1.07218s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 1/10: total=1.3616s kernel=0.1369s h2d=0.00758s d2h=1.21535s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 2/10: total=1.2208s kernel=0.1445s h2d=0.01421s d2h=1.06006s gpu_mem=0.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 3/10: total=1.1814s kernel=0.1370s h2d=0.00559s d2h=1.03706s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 4/10: total=1.2207s kernel=0.1456s h2d=0.01135s d2h=1.06193s gpu_mem=0.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 5/10: total=1.1999s kernel=0.1364s h2d=0.00517s d2h=1.05636s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 6/10: total=1.2138s kernel=0.1448s h2d=0.00810s d2h=1.05911s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 7/10: total=1.1982s kernel=0.1363s h2d=0.00503s d2h=1.05514s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 8/10: total=1.2050s kernel=0.1442s h2d=0.00732s d2h=1.05167s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 9/10: total=1.2158s kernel=0.1362s h2d=0.00476s d2h=1.07306s gpu_mem=2866.0MB
# [vase] dtype=float32 n1=1250 n2=5000 run 10/10: total=1.3021s kernel=0.1394s h2d=0.00722s d2h=1.15375s gpu_mem=2866.0MB
#
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Numba_GPU_stats_banana_Colab.csv, /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Numba_GPU_stats_apple_Colab.csv, and /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/Numba_GPU_stats_vase_Colab.csv.
#
#
# ---------------------------------------------------------------------------
# ⏱️ Benchmarking Phase Completed
# ---------------------------------------------------------------------------
# 🕒 Total benchmarking time: 3.09 minutes
# 📈 Timing data collected for all datasets and parameter combinations.
# ---------------------------------------------------------------------------
#
#
# ===========================================================================
# 🎨 Final Surface Reconstruction & Visualization
# ===========================================================================
#
#
# ===========================================================================
# 📄 Visualization Completed Successfully 🎉
# ===========================================================================
#
#
#
# ===== Running reconstruct_pytorch_gpu.py =====
#
#
# ===========================================================================
# 🚀 Surface Reconstruction Benchmark (PyTorch Vectorized | GPU)
# ===========================================================================
# 🔬 Purpose  : Performance benchmarking for surface reconstruction
# 📊 Datasets : Banana, Apple, Vase
# 🧮 Parameters:
#    • n1 (horizontal points) : [300, 625, 1250]
#    • n2 (vertical points)   : [1200, 2500, 5000]
#    • Data types             : ['float64', 'float32']
#
# ⏳ This is a GPU-intensive benchmark.
# [banana] dtype=float64 n1=300 n2=1200 run 1/10: total=0.2616s kernel=0.0221s h2d=0.00019s d2h=0.18789s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 2/10: total=0.2614s kernel=0.0221s h2d=0.00019s d2h=0.18834s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 3/10: total=0.2712s kernel=0.0221s h2d=0.00021s d2h=0.19198s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 4/10: total=0.2624s kernel=0.0221s h2d=0.00018s d2h=0.19077s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 5/10: total=0.2625s kernel=0.0221s h2d=0.00019s d2h=0.18660s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 6/10: total=0.2622s kernel=0.0221s h2d=0.00019s d2h=0.18962s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 7/10: total=0.2781s kernel=0.0220s h2d=0.00017s d2h=0.20402s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 8/10: total=0.2620s kernel=0.0221s h2d=0.00019s d2h=0.18532s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 9/10: total=0.2676s kernel=0.0221s h2d=0.00018s d2h=0.19180s peak_mem=404.9MB
# [banana] dtype=float64 n1=300 n2=1200 run 10/10: total=0.2700s kernel=0.0221s h2d=0.00020s d2h=0.19410s peak_mem=404.9MB
# [apple] dtype=float64 n1=300 n2=1200 run 1/10: total=0.3405s kernel=0.0269s h2d=0.00020s d2h=0.25413s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 2/10: total=0.3273s kernel=0.0269s h2d=0.00022s d2h=0.24070s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 3/10: total=0.3389s kernel=0.0269s h2d=0.00021s d2h=0.24049s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 4/10: total=0.3200s kernel=0.0268s h2d=0.00022s d2h=0.23740s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 5/10: total=0.3270s kernel=0.0268s h2d=0.00019s d2h=0.24192s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 6/10: total=0.3336s kernel=0.0271s h2d=0.00022s d2h=0.24675s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 7/10: total=0.3261s kernel=0.0268s h2d=0.00021s d2h=0.24408s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 8/10: total=0.3326s kernel=0.0268s h2d=0.00022s d2h=0.24453s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 9/10: total=0.3653s kernel=0.0269s h2d=0.00021s d2h=0.27653s peak_mem=515.0MB
# [apple] dtype=float64 n1=300 n2=1200 run 10/10: total=0.3939s kernel=0.0272s h2d=0.00024s d2h=0.28660s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 1/10: total=0.3865s kernel=0.0274s h2d=0.00024s d2h=0.27883s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 2/10: total=0.4187s kernel=0.0274s h2d=0.00026s d2h=0.31250s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 3/10: total=0.4241s kernel=0.0276s h2d=0.00028s d2h=0.30614s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 4/10: total=0.3943s kernel=0.0277s h2d=0.00027s d2h=0.26415s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 5/10: total=0.3363s kernel=0.0272s h2d=0.00020s d2h=0.24257s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 6/10: total=0.3376s kernel=0.0272s h2d=0.00027s d2h=0.24415s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 7/10: total=0.3318s kernel=0.0272s h2d=0.00021s d2h=0.24224s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 8/10: total=0.3316s kernel=0.0272s h2d=0.00020s d2h=0.23721s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 9/10: total=0.3308s kernel=0.0273s h2d=0.00020s d2h=0.24260s peak_mem=515.0MB
# [vase] dtype=float64 n1=300 n2=1200 run 10/10: total=0.3242s kernel=0.0273s h2d=0.00019s d2h=0.23414s peak_mem=515.0MB
# [banana] dtype=float32 n1=300 n2=1200 run 1/10: total=0.1598s kernel=0.0112s h2d=0.00020s d2h=0.09457s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 2/10: total=0.1624s kernel=0.0112s h2d=0.00020s d2h=0.10061s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 3/10: total=0.1624s kernel=0.0118s h2d=0.00024s d2h=0.09748s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 4/10: total=0.1581s kernel=0.0112s h2d=0.00019s d2h=0.09576s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 5/10: total=0.1601s kernel=0.0114s h2d=0.00018s d2h=0.09248s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 6/10: total=0.1639s kernel=0.0112s h2d=0.00019s d2h=0.09837s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 7/10: total=0.1639s kernel=0.0112s h2d=0.00019s d2h=0.09694s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 8/10: total=0.1562s kernel=0.0112s h2d=0.00018s d2h=0.09267s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 9/10: total=0.1701s kernel=0.0115s h2d=0.00024s d2h=0.09579s peak_mem=208.5MB
# [banana] dtype=float32 n1=300 n2=1200 run 10/10: total=0.1582s kernel=0.0111s h2d=0.00020s d2h=0.09463s peak_mem=208.5MB
# [apple] dtype=float32 n1=300 n2=1200 run 1/10: total=0.1949s kernel=0.0134s h2d=0.00025s d2h=0.11971s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 2/10: total=0.1964s kernel=0.0134s h2d=0.00020s d2h=0.12364s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 3/10: total=0.2100s kernel=0.0134s h2d=0.00020s d2h=0.13595s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 4/10: total=0.1991s kernel=0.0134s h2d=0.00019s d2h=0.12280s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 5/10: total=0.2003s kernel=0.0134s h2d=0.00027s d2h=0.12006s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 6/10: total=0.1981s kernel=0.0134s h2d=0.00021s d2h=0.12506s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 7/10: total=0.1936s kernel=0.0134s h2d=0.00022s d2h=0.11787s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 8/10: total=0.1920s kernel=0.0133s h2d=0.00019s d2h=0.12444s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 9/10: total=0.1849s kernel=0.0134s h2d=0.00020s d2h=0.11526s peak_mem=262.6MB
# [apple] dtype=float32 n1=300 n2=1200 run 10/10: total=0.1894s kernel=0.0134s h2d=0.00021s d2h=0.11497s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 1/10: total=0.1973s kernel=0.0136s h2d=0.00018s d2h=0.12156s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 2/10: total=0.2053s kernel=0.0136s h2d=0.00019s d2h=0.13056s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 3/10: total=0.2024s kernel=0.0136s h2d=0.00022s d2h=0.12281s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 4/10: total=0.2012s kernel=0.0135s h2d=0.00036s d2h=0.11772s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 5/10: total=0.2147s kernel=0.0136s h2d=0.00022s d2h=0.13786s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 6/10: total=0.1917s kernel=0.0135s h2d=0.00026s d2h=0.11557s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 7/10: total=0.2016s kernel=0.0138s h2d=0.00017s d2h=0.12724s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 8/10: total=0.2013s kernel=0.0135s h2d=0.00018s d2h=0.12221s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 9/10: total=0.1994s kernel=0.0136s h2d=0.00022s d2h=0.11995s peak_mem=262.6MB
# [vase] dtype=float32 n1=300 n2=1200 run 10/10: total=0.2016s kernel=0.0135s h2d=0.00017s d2h=0.12150s peak_mem=262.6MB
# [banana] dtype=float64 n1=625 n2=2500 run 1/10: total=1.1544s kernel=0.0905s h2d=0.00021s d2h=1.00496s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 2/10: total=1.2407s kernel=0.0869s h2d=0.00028s d2h=1.07422s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 3/10: total=1.0966s kernel=0.0880s h2d=0.00029s d2h=0.92637s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 4/10: total=1.0156s kernel=0.0873s h2d=0.00035s d2h=0.86071s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 5/10: total=0.9849s kernel=0.0878s h2d=0.00023s d2h=0.83670s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 6/10: total=0.9578s kernel=0.0878s h2d=0.00024s d2h=0.81099s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 7/10: total=1.0005s kernel=0.0877s h2d=0.00022s d2h=0.85098s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 8/10: total=0.9992s kernel=0.0878s h2d=0.00021s d2h=0.84049s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 9/10: total=0.9763s kernel=0.0878s h2d=0.00034s d2h=0.82861s peak_mem=1727.9MB
# [banana] dtype=float64 n1=625 n2=2500 run 10/10: total=0.9744s kernel=0.0878s h2d=0.00023s d2h=0.82320s peak_mem=1727.9MB
# [apple] dtype=float64 n1=625 n2=2500 run 1/10: total=1.2497s kernel=0.1064s h2d=0.00022s d2h=1.07795s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 2/10: total=1.4104s kernel=0.1067s h2d=0.00024s d2h=1.23500s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 3/10: total=1.3711s kernel=0.1066s h2d=0.00023s d2h=1.18490s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 4/10: total=1.1936s kernel=0.1063s h2d=0.00021s d2h=1.02445s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 5/10: total=1.1818s kernel=0.1064s h2d=0.00022s d2h=1.00576s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 6/10: total=1.1873s kernel=0.1062s h2d=0.00022s d2h=1.02047s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 7/10: total=1.2350s kernel=0.1064s h2d=0.00022s d2h=1.06136s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 8/10: total=1.1839s kernel=0.1063s h2d=0.00022s d2h=1.01470s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 9/10: total=1.1928s kernel=0.1063s h2d=0.00021s d2h=1.02241s peak_mem=2206.0MB
# [apple] dtype=float64 n1=625 n2=2500 run 10/10: total=1.1692s kernel=0.1062s h2d=0.00021s d2h=1.00271s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 1/10: total=1.4707s kernel=0.1087s h2d=0.00022s d2h=1.24830s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 2/10: total=1.3557s kernel=0.1084s h2d=0.00024s d2h=1.16052s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 3/10: total=1.1730s kernel=0.1080s h2d=0.00020s d2h=0.99847s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 4/10: total=1.1993s kernel=0.1081s h2d=0.00023s d2h=1.02485s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 5/10: total=1.1997s kernel=0.1080s h2d=0.00019s d2h=1.01000s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 6/10: total=1.1657s kernel=0.1080s h2d=0.00019s d2h=0.99161s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 7/10: total=1.1760s kernel=0.1080s h2d=0.00019s d2h=1.00100s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 8/10: total=1.1711s kernel=0.1081s h2d=0.00022s d2h=0.99477s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 9/10: total=1.2154s kernel=0.1082s h2d=0.00029s d2h=1.03798s peak_mem=2206.0MB
# [vase] dtype=float64 n1=625 n2=2500 run 10/10: total=1.2011s kernel=0.1081s h2d=0.00025s d2h=1.02287s peak_mem=2206.0MB
# [banana] dtype=float32 n1=625 n2=2500 run 1/10: total=0.6075s kernel=0.0446s h2d=0.00023s d2h=0.48901s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 2/10: total=0.6429s kernel=0.0440s h2d=0.00023s d2h=0.53196s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 3/10: total=0.6287s kernel=0.0442s h2d=0.00024s d2h=0.51083s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 4/10: total=0.5142s kernel=0.0442s h2d=0.00020s d2h=0.41135s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 5/10: total=0.5031s kernel=0.0439s h2d=0.00027s d2h=0.40667s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 6/10: total=0.5016s kernel=0.0442s h2d=0.00020s d2h=0.40049s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 7/10: total=0.5034s kernel=0.0440s h2d=0.00028s d2h=0.40670s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 8/10: total=0.4996s kernel=0.0444s h2d=0.00020s d2h=0.40145s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 9/10: total=0.4997s kernel=0.0441s h2d=0.00019s d2h=0.40454s peak_mem=869.6MB
# [banana] dtype=float32 n1=625 n2=2500 run 10/10: total=0.5110s kernel=0.0444s h2d=0.00028s d2h=0.40965s peak_mem=869.6MB
# [apple] dtype=float32 n1=625 n2=2500 run 1/10: total=0.6206s kernel=0.0537s h2d=0.00019s d2h=0.50470s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 2/10: total=0.6460s kernel=0.0538s h2d=0.00024s d2h=0.51722s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 3/10: total=0.6257s kernel=0.0531s h2d=0.00029s d2h=0.51051s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 4/10: total=0.6148s kernel=0.0536s h2d=0.00019s d2h=0.50431s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 5/10: total=0.6375s kernel=0.0537s h2d=0.00025s d2h=0.52744s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 6/10: total=0.6177s kernel=0.0537s h2d=0.00019s d2h=0.50397s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 7/10: total=0.6087s kernel=0.0537s h2d=0.00019s d2h=0.49627s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 8/10: total=0.6183s kernel=0.0536s h2d=0.00019s d2h=0.50518s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 9/10: total=0.6116s kernel=0.0530s h2d=0.00018s d2h=0.50017s peak_mem=1107.2MB
# [apple] dtype=float32 n1=625 n2=2500 run 10/10: total=0.7833s kernel=0.0531s h2d=0.00031s d2h=0.63414s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 1/10: total=0.8259s kernel=0.0540s h2d=0.00034s d2h=0.66626s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 2/10: total=0.6190s kernel=0.0549s h2d=0.00021s d2h=0.49701s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 3/10: total=0.6269s kernel=0.0538s h2d=0.00021s d2h=0.50857s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 4/10: total=0.6425s kernel=0.0539s h2d=0.00019s d2h=0.52384s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 5/10: total=0.6250s kernel=0.0548s h2d=0.00019s d2h=0.49582s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 6/10: total=0.6407s kernel=0.0546s h2d=0.00021s d2h=0.52132s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 7/10: total=0.6282s kernel=0.0538s h2d=0.00020s d2h=0.51102s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 8/10: total=0.6391s kernel=0.0536s h2d=0.00020s d2h=0.51941s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 9/10: total=0.6415s kernel=0.0544s h2d=0.00021s d2h=0.51921s peak_mem=1107.2MB
# [vase] dtype=float32 n1=625 n2=2500 run 10/10: total=0.6149s kernel=0.0546s h2d=0.00021s d2h=0.49843s peak_mem=1107.2MB
# [banana] dtype=float64 n1=1250 n2=5000 run 1/10: total=4.3000s kernel=0.3713s h2d=0.00021s d2h=3.85165s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 2/10: total=3.6889s kernel=0.3679s h2d=0.00034s d2h=3.23787s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 3/10: total=3.6293s kernel=0.3712s h2d=0.00021s d2h=3.18309s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 4/10: total=4.0691s kernel=0.3717s h2d=0.00020s d2h=3.62347s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 5/10: total=3.6593s kernel=0.3679s h2d=0.00020s d2h=3.21862s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 6/10: total=3.7453s kernel=0.3719s h2d=0.00025s d2h=3.29951s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 7/10: total=4.1751s kernel=0.3678s h2d=0.00022s d2h=3.72921s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 8/10: total=3.7671s kernel=0.3649s h2d=0.00029s d2h=3.30639s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 9/10: total=3.6756s kernel=0.3715s h2d=0.00020s d2h=3.23025s peak_mem=6879.6MB
# [banana] dtype=float64 n1=1250 n2=5000 run 10/10: total=3.9020s kernel=0.3736s h2d=0.00021s d2h=3.45551s peak_mem=6879.6MB
# [apple] dtype=float64 n1=1250 n2=5000 run 1/10: total=4.5576s kernel=0.4827s h2d=0.00020s d2h=3.98990s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 2/10: total=5.0308s kernel=0.4710s h2d=0.00021s d2h=4.46431s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 3/10: total=4.5589s kernel=0.4775s h2d=0.00021s d2h=3.99657s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 4/10: total=4.5928s kernel=0.4825s h2d=0.00020s d2h=4.02748s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 5/10: total=4.9201s kernel=0.4489s h2d=0.00029s d2h=4.35918s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 6/10: total=4.5877s kernel=0.4828s h2d=0.00020s d2h=4.01992s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 7/10: total=5.0243s kernel=0.4804s h2d=0.00022s d2h=4.45694s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 8/10: total=4.7479s kernel=0.4481s h2d=0.00032s d2h=4.17937s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 9/10: total=4.5924s kernel=0.4824s h2d=0.00021s d2h=4.02511s peak_mem=8788.3MB
# [apple] dtype=float64 n1=1250 n2=5000 run 10/10: total=4.9642s kernel=0.4832s h2d=0.00022s d2h=4.39604s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 1/10: total=4.9161s kernel=0.4805s h2d=0.00021s d2h=4.34234s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 2/10: total=4.6746s kernel=0.4626s h2d=0.00026s d2h=4.10408s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 3/10: total=4.6128s kernel=0.4846s h2d=0.00021s d2h=4.03806s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 4/10: total=5.0863s kernel=0.4763s h2d=0.00037s d2h=4.51373s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 5/10: total=4.6369s kernel=0.4851s h2d=0.00022s d2h=4.06155s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 6/10: total=4.8228s kernel=0.4835s h2d=0.00023s d2h=4.24819s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 7/10: total=4.7494s kernel=0.4567s h2d=0.00023s d2h=4.18156s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 8/10: total=4.5697s kernel=0.4840s h2d=0.00020s d2h=3.99439s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 9/10: total=5.0858s kernel=0.4805s h2d=0.00021s d2h=4.51091s peak_mem=8788.3MB
# [vase] dtype=float64 n1=1250 n2=5000 run 10/10: total=4.5781s kernel=0.4784s h2d=0.00020s d2h=4.00736s peak_mem=8788.3MB
# [banana] dtype=float32 n1=1250 n2=5000 run 1/10: total=1.8444s kernel=0.1746s h2d=0.00021s d2h=1.60783s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 2/10: total=2.1164s kernel=0.1752s h2d=0.00020s d2h=1.87908s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 3/10: total=2.1801s kernel=0.1758s h2d=0.00032s d2h=1.92539s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 4/10: total=1.8853s kernel=0.1809s h2d=0.00022s d2h=1.63772s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 5/10: total=1.8593s kernel=0.1747s h2d=0.00020s d2h=1.62037s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 6/10: total=1.8579s kernel=0.1751s h2d=0.00020s d2h=1.61974s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 7/10: total=1.8867s kernel=0.1738s h2d=0.00022s d2h=1.64769s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 8/10: total=1.8465s kernel=0.1742s h2d=0.00019s d2h=1.60924s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 9/10: total=2.2435s kernel=0.1727s h2d=0.00018s d2h=1.98570s peak_mem=3444.6MB
# [banana] dtype=float32 n1=1250 n2=5000 run 10/10: total=1.9116s kernel=0.1778s h2d=0.00029s d2h=1.63794s peak_mem=3444.6MB
# [apple] dtype=float32 n1=1250 n2=5000 run 1/10: total=2.3450s kernel=0.2215s h2d=0.00021s d2h=2.05197s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 2/10: total=2.4221s kernel=0.2236s h2d=0.00022s d2h=2.13006s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 3/10: total=2.7698s kernel=0.2213s h2d=0.00025s d2h=2.46869s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 4/10: total=2.4676s kernel=0.2210s h2d=0.00029s d2h=2.14060s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 5/10: total=2.3458s kernel=0.2218s h2d=0.00022s d2h=2.05046s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 6/10: total=2.4033s kernel=0.2223s h2d=0.00020s d2h=2.11067s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 7/10: total=2.3454s kernel=0.2215s h2d=0.00047s d2h=2.04365s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 8/10: total=2.6029s kernel=0.2211s h2d=0.00031s d2h=2.31024s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 9/10: total=2.4246s kernel=0.2198s h2d=0.00024s d2h=2.10669s peak_mem=4399.7MB
# [apple] dtype=float32 n1=1250 n2=5000 run 10/10: total=2.3026s kernel=0.2220s h2d=0.00021s d2h=2.00907s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 1/10: total=2.3764s kernel=0.2244s h2d=0.00020s d2h=2.07741s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 2/10: total=2.6041s kernel=0.2219s h2d=0.00031s d2h=2.28373s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 3/10: total=2.5597s kernel=0.2229s h2d=0.00023s d2h=2.24121s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 4/10: total=2.3182s kernel=0.2242s h2d=0.00020s d2h=2.01935s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 5/10: total=2.3297s kernel=0.2234s h2d=0.00026s d2h=2.03171s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 6/10: total=2.3081s kernel=0.2241s h2d=0.00022s d2h=2.00628s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 7/10: total=2.4818s kernel=0.2229s h2d=0.00020s d2h=2.18419s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 8/10: total=2.6625s kernel=0.2204s h2d=0.00024s d2h=2.33709s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 9/10: total=2.3059s kernel=0.2233s h2d=0.00024s d2h=2.00801s peak_mem=4399.7MB
# [vase] dtype=float32 n1=1250 n2=5000 run 10/10: total=2.3541s kernel=0.2246s h2d=0.00025s d2h=2.05385s peak_mem=4399.7MB
#
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/TensorV_GPU_stats_banana_Colab.csv, /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/TensorV_GPU_stats_apple_Colab.csv, and /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/TensorV_GPU_stats_vase_Colab.csv.
#
#
# ---------------------------------------------------------------------------
# ⏱️ Benchmarking Phase Completed
# ---------------------------------------------------------------------------
# 🕒 Total benchmarking time: 5.03 minutes
# 📈 Timing data collected for all datasets and parameter combinations.
# ---------------------------------------------------------------------------
#
#
# ===========================================================================
# 🎨 Final Surface Reconstruction & Visualization
# ===========================================================================
#
#
# ===========================================================================
# 📄 Visualization Completed Successfully 🎉
# ===========================================================================
#
#
#
# ✅ All scripts completed successfully.

# %%
# Generate the final tables and figures used in the manuscript.
#
# This script aggregates the benchmark results produced by the CPU and GPU
# benchmark pipelines, computes summary statistics, and generates all
# publication-quality tables and figures reported in the paper.
#
# Note:
# • The GitHub repository already includes the benchmark results generated
#   by the CPU and GPU driver scripts. Therefore, this cell can be executed
#   directly without rerunning the benchmark pipelines if you only wish to
#   reproduce the tables and figures.
# • This script runs entirely on the CPU and does not require a GPU.
#
# Ensure that the CPU and GPU benchmark results are available before
# running this script, either by executing the benchmark driver scripts
# above or by using the precomputed results included in the repository.

# !python driver\ scripts/aggregate_results_generate_plots.py
# Out:
# ===== Running info.py =====
#
#
# ===========================================================================
# 🚀 Diagnostic cell: captures exact hardware/software identity for the
# 🚀 Experimental Setup section (CPU model name, CPUID family/model number,
# 🚀 full Linux distribution, NumPy/Numba SIMD dispatch).
# ===========================================================================
# cpu_family: 6
# cpu_model_number: 79
# cpu_model_name: Intel(R) Xeon(R) CPU @ 2.20GHz
# distro: Ubuntu 22.04.5 LTS
# kernel: 6.6.122+
# numpy_version: 2.0.2
# numpy_simd: {'baseline': ['SSE', 'SSE2', 'SSE3'], 'found': ['SSSE3', 'SSE41', 'POPCNT', 'SSE42', 'AVX', 'F16C', 'FMA3', 'AVX2'], 'not found': ['AVX512F', 'AVX512CD', 'AVX512_KNL', 'AVX512_KNM', 'AVX512_SKX', 'AVX512_CLX', 'AVX512_CNL', 'AVX512_ICL']}
# numba_version: 0.60.0
# numba_target_cpu: host (auto-detected)
# numba_target_features: None
#
# ===== Running aggregate_results.py =====
#
# Saved (memory-corrected): /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/master_long_format_Colab.csv
# Saved: master_long_format.csv ( 252 rows )
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/merged_table_Colab.csv
# col             NumPy-vectorized (1 thread) (Colab)  ...  Serial Python (Kaggle)
# object dtype                                         ...
# apple  float32                             8.808895  ...                8.105146
#        float64                            14.596229  ...                9.542883
# banana float32                             7.576347  ...                6.710650
#        float64                            11.806800  ...                7.737848
# vase   float32                             9.432558  ...                8.349730
#        float64                            14.934056  ...                9.693324
#
# [6 rows x 14 columns]
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/merged_table_with_precision_Colab.csv
# Saved: /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/memory_transfer_table_Colab.csv and /content/Reconstruction-of-3D-Objects-and-Parallelisation/results/csv files/memory_transfer_table_gpu_transfer_vs_kernel_Colab.csv
#
# ===== Running generate_figures.py =====
#
# /content/Reconstruction-of-3D-Objects-and-Parallelisation/code/generate_figures.py:163: RuntimeWarning: All-NaN slice encountered
#   min_per_i = np.nanmin(mag, axis=1)
#
# ✅ All scripts completed successfully.
